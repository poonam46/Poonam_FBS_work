# %%
x = 10

# %%
x
# Out:
# 10

# %%
x
# Out:
# 10

# %% [markdown]
# This is demo for jupyter

# %% [markdown]
# # Markdown Demo

# %% [markdown]
# # This
# ## This
# ### This
# #### This
# ##### This
