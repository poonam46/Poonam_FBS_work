# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv("C:/Users/Windows 10/Desktop/Rakhi_FBS/Data Analysis/DataSets/Iris.csv")

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.columns
# Out:
# Index(['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width',
#        'Species'],
#       dtype='str')

# %%
iris.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris['Species'].unique()
# Out:
# <StringArray>
# ['Setosa', 'Versicolor', 'Virginica']
# Length: 3, dtype: str

# %%
iris.value_counts()
# Out:
# Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Species
# 4.9           3.1          1.5           0.1          Setosa       3
# 5.8           2.7          5.1           1.9          Virginica    2
# 5.1           3.5          1.4           0.2          Setosa       1
# 4.9           3.0          1.4           0.2          Setosa       1
# 4.7           3.2          1.3           0.2          Setosa       1
#                                                                   ..
# 6.7           3.0          5.2           2.3          Virginica    1
# 6.3           2.5          5.0           1.9          Virginica    1
# 6.5           3.0          5.2           2.0          Virginica    1
# 6.2           3.4          5.4           2.3          Virginica    1
# 5.9           3.0          5.1           1.8          Virginica    1
# Name: count, Length: 147, dtype: int64

# %%
iris['Species'].value_counts()
# Out:
# Species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
sns.scatterplot(data = iris, x='Sepal_Length', y='Sepal_Width', hue='Species')
# Out:
# <Axes: xlabel='Sepal_Length', ylabel='Sepal_Width'>

# %%
iris.plot(kind='scatter', x='Sepal_Length', y='Sepal_Width')
# Out:
# <Axes: xlabel='Sepal_Length', ylabel='Sepal_Width'>

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris, hue='Species').map(plt.scatter, 'Sepal_Length', 'Sepal_Width').add_legend()

# %%
setosa = iris.loc[iris['Species'] == 'Setosa']
setosa['Species'].unique()
# Out:
# <StringArray>
# ['Setosa']
# Length: 1, dtype: str

# %%
setosa.shape
# Out:
# (50, 5)

# %%
versicolor = iris.loc[iris['Species'] == 'Versicolor']
versicolor['Species'].unique()
# Out:
# <StringArray>
# ['Versicolor']
# Length: 1, dtype: str

# %%
versicolor.shape
# Out:
# (50, 5)

# %%
virginica = iris.loc[iris['Species'] == 'Virginica']
virginica['Species'].unique()
# Out:
# <StringArray>
# ['Virginica']
# Length: 1, dtype: str

# %%
virginica.shape
# Out:
# (50, 5)

# %%
plt.plot(setosa['Petal_Length'], np.zeros_like(setosa['Petal_Length']), 'o', label='Setosa')
plt.plot(versicolor['Petal_Length'], np.zeros_like(versicolor['Petal_Length']), 'o', label='Versicolor')
plt.plot(virginica['Petal_Length'], np.zeros_like(virginica['Petal_Length']), 'o', label='Virginica')
plt.xlabel('Petal Length')
plt.legend()
plt.show()

# %% [markdown]
# 1. Setosa - Petal length between 1 to 2
# 2. Versicolor - Petal length between 3 to 4.5
# 3. Virginica - Petal length between 5 to 7

# %%
sns.histplot(data=iris, x='Petal_Length', hue='Species', element='step')
# Out:
# <Axes: xlabel='Petal_Length', ylabel='Count'>

# %%
sns.histplot(data=iris, x='Petal_Length', hue='Species', element='step', stat='density', common_norm=False)
sns.kdeplot(data=iris, x='Petal_Length', hue='Species', common_norm=False, fill=False)
plt.plot()
# Out:
# []

# %%
sns.histplot(data=iris, x='Petal_Width', hue='Species', element='step', stat='density', common_norm=False)
sns.kdeplot(data=iris, x='Petal_Width', hue='Species', common_norm=False, fill=False)
plt.plot()
# Out:
# []

# %%
sns.histplot(data=iris, x='Sepal_Length', hue='Species', element='step', stat='density')
sns.kdeplot(data=iris, x='Sepal_Length', hue='Species')
plt.plot()
# Out:
# []

# %%
sns.histplot(data=iris, x='Sepal_Width', hue='Species', element='step', stat='density')
sns.kdeplot(data=iris, x='Sepal_Width', hue='Species')
plt.plot()
# Out:
# []

# %%
iris.describe()
# Out:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#Box Plot
sns.boxplot(x='Species', y='Petal_Length', data=iris, hue='Species')
plt.title('Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length')
plt.show()

# %%
sns.scatterplot(data = iris, x='Petal_Length', y='Petal_Width', hue='Species')
# Out:
# <Axes: xlabel='Petal_Length', ylabel='Petal_Width'>

# %%
q1 = iris['Petal_Length'].quantile(0.25)
q1
# Out:
# np.float64(1.6)

# %%
q3 = iris['Petal_Length'].quantile(0.75)
q3
# Out:
# np.float64(5.1)

# %%
iqr = q3 - q1
iqr
# Out:
# np.float64(3.4999999999999996)

# %%
lower = q1 - 1.5 * iqr
lower
# Out:
# np.float64(-3.649999999999999)

# %%
iris.describe()
# Out:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
setosa.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
#Box Plot
sns.boxplot(x='Species', y='Petal_Length', data=setosa, hue='Species')
plt.title('Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length')
plt.show()

# %%
q1 = setosa['Petal_Length'].quantile(0.25)
q1
# Out:
# np.float64(1.4)

# %%
q3 = setosa['Petal_Length'].quantile(0.75)
q3
# Out:
# np.float64(1.5750000000000002)

# %%
iqr = q3 - q1
iqr
# Out:
# np.float64(0.17500000000000027)

# %%
lower = q1 - 1.5 * iqr
lower
# Out:
# np.float64(1.1374999999999995)

# %%
upper = q3 + 1.5 * iqr
upper
# Out:
# np.float64(1.8375000000000006)

# %%
setosa.loc[setosa['Petal_Length'] >= 1.7, 'Petal_Length']=1.7

# %%
#Box Plot
sns.boxplot(x='Species', y='Petal_Length', data=setosa, hue='Species')
plt.title('Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length')
plt.show()

# %%
setosa.loc[setosa['Petal_Length'] < 1.2, 'Petal_Length']=1.2

# %%
#Box Plot
sns.boxplot(x='Species', y='Petal_Length', data=setosa, hue='Species')
plt.title('Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length')
plt.show()
