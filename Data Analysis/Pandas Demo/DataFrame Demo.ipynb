# %% [markdown]
# #### Intro
# 1. Pandas dataframe is two dimensional
# 2. Size mutable
# 3. Heterogeneous tabular data structure
# 4. Labeeled axes(rows and columns)

# %%
import pandas as pd

# %%
df = pd.DataFrame([[101,'Poonam','Data Scientist'],[102,'Rakhi','Data Analyst'],[103,'Jagruti','Developer']])
df
# Out:
#      0        1               2
# 0  101   Poonam  Data Scientist
# 1  102    Rakhi    Data Analyst
# 2  103  Jagruti       Developer

# %%
df = pd.DataFrame([[101,'Poonam','Data Scientist'],[102,'Rakhi','Data Analyst'],[103,'Jagruti','Developer']], columns = ["ID","NAME","DEPT"])
df
# Out:
#     ID     NAME            DEPT
# 0  101   Poonam  Data Scientist
# 1  102    Rakhi    Data Analyst
# 2  103  Jagruti       Developer

# %%
df.index = df['ID']
df
# Out:
#       ID     NAME            DEPT
# ID
# 101  101   Poonam  Data Scientist
# 102  102    Rakhi    Data Analyst
# 103  103  Jagruti       Developer

# %%
df['ID']
# Out:
# ID
# 101    101
# 102    102
# 103    103
# Name: ID, dtype: int64

# %%
df['NAME']
# Out:
# ID
# 101     Poonam
# 102      Rakhi
# 103    Jagruti
# Name: NAME, dtype: object

# %%
ids = [101, 102, 103, 104, 105]
names = ["Poonam", "Rakhi", "Jagruti", "Harshal", "Ayush"]
sal = [30000, 40000, 50000, 60000, 70000]
dept = ["AI Engineer", "Data Scienist", "Software Developer", "Data Scientist", "Gen AI Engineer"]

df2 = pd.DataFrame({"ID" : ids, "NAME" : names, "SALARY" : sal, "DEPT" : dept})
df2
# Out:
#     ID     NAME  SALARY                DEPT
# 0  101   Poonam   30000         AI Engineer
# 1  102    Rakhi   40000       Data Scienist
# 2  103  Jagruti   50000  Software Developer
# 3  104  Harshal   60000      Data Scientist
# 4  105    Ayush   70000     Gen AI Engineer

# %%
df
# Out:
#       ID     NAME            DEPT
# ID
# 101  101   Poonam  Data Scientist
# 102  102    Rakhi    Data Analyst
# 103  103  Jagruti       Developer

# %%
df.index = df["NAME"]
df
# Out:
#           ID     NAME            DEPT
# NAME
# Poonam   101   Poonam  Data Scientist
# Rakhi    102    Rakhi    Data Analyst
# Jagruti  103  Jagruti       Developer

# %%
df.index = ['a','b','c']
df
# Out:
#     ID     NAME            DEPT
# a  101   Poonam  Data Scientist
# b  102    Rakhi    Data Analyst
# c  103  Jagruti       Developer

# %%
df2
# Out:
#     ID     NAME  SALARY                DEPT
# 0  101   Poonam   30000         AI Engineer
# 1  102    Rakhi   40000       Data Scienist
# 2  103  Jagruti   50000  Software Developer
# 3  104  Harshal   60000      Data Scientist
# 4  105    Ayush   70000     Gen AI Engineer

# %%
df2.head()
# Out:
#     ID     NAME  SALARY                DEPT
# 0  101   Poonam   30000         AI Engineer
# 1  102    Rakhi   40000       Data Scienist
# 2  103  Jagruti   50000  Software Developer
# 3  104  Harshal   60000      Data Scientist
# 4  105    Ayush   70000     Gen AI Engineer

# %%
df2.tail()
# Out:
#     ID     NAME  SALARY                DEPT
# 0  101   Poonam   30000         AI Engineer
# 1  102    Rakhi   40000       Data Scienist
# 2  103  Jagruti   50000  Software Developer
# 3  104  Harshal   60000      Data Scientist
# 4  105    Ayush   70000     Gen AI Engineer

# %%
df2['SALARY'].mean()
# Out:
# 50000.0

# %%
df2['SALARY'].max()
# Out:
# 70000

# %%
df2['SALARY'].min()
# Out:
# 30000

# %%
df2.max()
# Out:
# ID                       105
# NAME                   Rakhi
# SALARY                 70000
# DEPT      Software Developer
# dtype: object

# %%
df2['DEPT'].unique()
# Out:
# array(['AI Engineer', 'Data Scienist', 'Software Developer',
#        'Data Scientist', 'Gen AI Engineer'], dtype=object)

# %%
df2['DEPT'].value_counts()
# Out:
# DEPT
# AI Engineer           1
# Data Scienist         1
# Software Developer    1
# Data Scientist        1
# Gen AI Engineer       1
# Name: count, dtype: int64

# %%
df2['DEPT'].nunique()    # Gives count of unique values
# Out:
# 5

# %%
df2['ADDRESS'] = ['Pune', 'Nashik', 'Mumbai', 'Thane', 'Deola']
df2
# Out:
#     ID     NAME  SALARY                DEPT ADDRESS
# 0  101   Poonam   30000         AI Engineer    Pune
# 1  102    Rakhi   40000       Data Scienist  Nashik
# 2  103  Jagruti   50000  Software Developer  Mumbai
# 3  104  Harshal   60000      Data Scientist   Thane
# 4  105    Ayush   70000     Gen AI Engineer   Deola

# %%
df2['NAME'] = ['Pune', 'Nashik', 'Mumbai', 'Thane', 'Deola']
df2
# Out:
#     ID    NAME  SALARY                DEPT ADDRESS
# 0  101    Pune   30000         AI Engineer    Pune
# 1  102  Nashik   40000       Data Scienist  Nashik
# 2  103  Mumbai   50000  Software Developer  Mumbai
# 3  104   Thane   60000      Data Scientist   Thane
# 4  105   Deola   70000     Gen AI Engineer   Deola

# %%
df2['NAME'] = ["Poonam", "Rakhi", "Jagruti", "Harshal", "Ayush"]
df2
# Out:
#     ID     NAME  SALARY                DEPT ADDRESS
# 0  101   Poonam   30000         AI Engineer    Pune
# 1  102    Rakhi   40000       Data Scienist  Nashik
# 2  103  Jagruti   50000  Software Developer  Mumbai
# 3  104  Harshal   60000      Data Scientist   Thane
# 4  105    Ayush   70000     Gen AI Engineer   Deola

# %%
df2.insert(2, value = [23, 20, 20, 18, 16] , column = 'AGE')
df2
# Out:
#     ID     NAME  AGE  SALARY                DEPT ADDRESS
# 0  101   Poonam   23   30000         AI Engineer    Pune
# 1  102    Rakhi   20   40000       Data Scienist  Nashik
# 2  103  Jagruti   20   50000  Software Developer  Mumbai
# 3  104  Harshal   18   60000      Data Scientist   Thane
# 4  105    Ayush   16   70000     Gen AI Engineer   Deola

# %%
df2.drop(2)
# Out:
#     ID     NAME  AGE  SALARY             DEPT ADDRESS
# 0  101   Poonam   23   30000      AI Engineer    Pune
# 1  102    Rakhi   20   40000    Data Scienist  Nashik
# 3  104  Harshal   18   60000   Data Scientist   Thane
# 4  105    Ayush   16   70000  Gen AI Engineer   Deola

# %%
df2
# Out:
#     ID     NAME  AGE  SALARY                DEPT ADDRESS
# 0  101   Poonam   23   30000         AI Engineer    Pune
# 1  102    Rakhi   20   40000       Data Scienist  Nashik
# 2  103  Jagruti   20   50000  Software Developer  Mumbai
# 3  104  Harshal   18   60000      Data Scientist   Thane
# 4  105    Ayush   16   70000     Gen AI Engineer   Deola

# %%
df2 = df2.drop(2)

# %%
df2
# Out:
#     ID     NAME  AGE  SALARY             DEPT ADDRESS
# 0  101   Poonam   23   30000      AI Engineer    Pune
# 1  102    Rakhi   20   40000    Data Scienist  Nashik
# 3  104  Harshal   18   60000   Data Scientist   Thane
# 4  105    Ayush   16   70000  Gen AI Engineer   Deola

# %%
df2.drop(4, inplace = True)

# %%
df2
# Out:
#     ID     NAME  AGE  SALARY            DEPT ADDRESS
# 0  101   Poonam   23   30000     AI Engineer    Pune
# 1  102    Rakhi   20   40000   Data Scienist  Nashik
# 3  104  Harshal   18   60000  Data Scientist   Thane

# %%
df2.drop('AGE' , axis = 1)
# Out:
#     ID     NAME  SALARY            DEPT ADDRESS
# 0  101   Poonam   30000     AI Engineer    Pune
# 1  102    Rakhi   40000   Data Scienist  Nashik
# 3  104  Harshal   60000  Data Scientist   Thane

# %%
df2
# Out:
#     ID     NAME  AGE  SALARY            DEPT ADDRESS
# 0  101   Poonam   23   30000     AI Engineer    Pune
# 1  102    Rakhi   20   40000   Data Scienist  Nashik
# 3  104  Harshal   18   60000  Data Scientist   Thane

# %%
df2 = df2.drop('AGE' , axis = 1)

# %%
df2
# Out:
#     ID     NAME  SALARY            DEPT ADDRESS
# 0  101   Poonam   30000     AI Engineer    Pune
# 1  102    Rakhi   40000   Data Scienist  Nashik
# 3  104  Harshal   60000  Data Scientist   Thane

# %%
df2.drop('ADDRESS' , axis = 1 , inplace = True)

# %%
df2
# Out:
#     ID     NAME  SALARY            DEPT
# 0  101   Poonam   30000     AI Engineer
# 1  102    Rakhi   40000   Data Scienist
# 3  104  Harshal   60000  Data Scientist

# %%
df2
# Out:
#     ID     NAME  SALARY            DEPT
# 0  101   Poonam   30000     AI Engineer
# 1  102    Rakhi   40000   Data Scienist
# 3  104  Harshal   60000  Data Scientist

# %%
df2.loc[1]
# Out:
# ID                  102
# NAME              Rakhi
# SALARY            40000
# DEPT      Data Scienist
# Name: 1, dtype: object

# %%
df2.index=df2['ID']
df2
# Out:
#       ID     NAME  SALARY            DEPT
# ID
# 101  101   Poonam   30000     AI Engineer
# 102  102    Rakhi   40000   Data Scienist
# 104  104  Harshal   60000  Data Scientist

# %%
df2.loc[102]
# Out:
# ID                  102
# NAME              Rakhi
# SALARY            40000
# DEPT      Data Scienist
# Name: 102, dtype: object

# %%
df2.iloc[1]
# Out:
# ID                  102
# NAME              Rakhi
# SALARY            40000
# DEPT      Data Scienist
# Name: 102, dtype: object

# %%
df2.loc[[101,102,104]]
# Out:
#       ID     NAME  SALARY            DEPT
# ID
# 101  101   Poonam   30000     AI Engineer
# 102  102    Rakhi   40000   Data Scienist
# 104  104  Harshal   60000  Data Scientist

# %%
df2.loc[df2['NAME'] == 'Rakhi' , 'SALARY'] = 80000

# %%
df2
# Out:
#       ID     NAME  SALARY            DEPT
# ID
# 101  101   Poonam   30000     AI Engineer
# 102  102    Rakhi   80000   Data Scienist
# 104  104  Harshal   60000  Data Scientist

# %%
df2.reset_index(drop = True)
# Out:
#     ID     NAME  SALARY            DEPT
# 0  101   Poonam   30000     AI Engineer
# 1  102    Rakhi   80000   Data Scienist
# 2  104  Harshal   60000  Data Scientist

# %%
df2.set_index('ID')
# Out:
#         NAME  SALARY            DEPT
# ID
# 101   Poonam   30000     AI Engineer
# 102    Rakhi   80000   Data Scienist
# 104  Harshal   60000  Data Scientist
