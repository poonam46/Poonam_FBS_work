# %%
#pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ### Introduction
# 1. Powerful data analysis toolkit
# 2. Open source
# 3. A fast and efficient dataframe object for data manipulation
# 4. Reading and writing data structures and different file formats : csv, excel, txt, xml, json,etc.
# 5. Numpy array is used for the implementation of pandas data objects.

# %% [markdown]
# ### Data Structures
# 1. series (1D)
# 2. Dataframe (2D)
# 3. Panel (3D)
