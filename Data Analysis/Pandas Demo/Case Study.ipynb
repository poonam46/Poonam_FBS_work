# %% [markdown]
# Sudents marks for 20 students with  6 subjects , gain marks , percentage
# 1. Create dataframe for 20 students marks

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.DataFrame(np.random.randint(30,100,(20,6)) , columns = ['Subject 1', 'Subject 2','Subject 3', 'Subject 4' ,'Subject 5' , 'Subject 6'])
df
# Out:
#     Subject 1  Subject 2  Subject 3  Subject 4  Subject 5  Subject 6
# 0          94         34         40         82         66         68
# 1          63         96         32         49         68         87
# 2          89         97         77         95         43         32
# 3          34         86         46         49         84         94
# 4          99         45         63         71         46         58
# 5          45         52         53         64         61         94
# 6          44         95         82         68         88         70
# 7          80         33         69         35         53         89
# 8          79         99         68         62         74         44
# 9          99         32         66         57         45         98
# 10         50         60         48         82         92         71
# 11         36         44         66         45         67         62
# 12         98         72         51         53         34         84
# ...

# %%
# sub1 = np.random.randint(30,100,20)
# sub2 = np.random.randint(30,100,20)


# df2 = pd.DataFrame({'Subject 1' : sub1 , 'Subject 2' : sub2})
# df2

# %%
# df['Gain Marks'] = df['Subject 1'] + df['Subject 2'] + df['Subject 3'] + df['Subject 4'] + df['Subject 5'] + df['Subject 6']
# df

# %%
df['Gain Marks'] = df[['Subject 1','Subject 2', 'Subject 3', 'Subject 4', 'Subject 5', 'Subject 6']].sum(axis = 1)
df
# Out:
#     Subject 1  Subject 2  Subject 3  Subject 4  Subject 5  Subject 6  \
# 0          94         34         40         82         66         68
# 1          63         96         32         49         68         87
# 2          89         97         77         95         43         32
# 3          34         86         46         49         84         94
# 4          99         45         63         71         46         58
# 5          45         52         53         64         61         94
# 6          44         95         82         68         88         70
# 7          80         33         69         35         53         89
# 8          79         99         68         62         74         44
# 9          99         32         66         57         45         98
# 10         50         60         48         82         92         71
# 11         36         44         66         45         67         62
# 12         98         72         51         53         34         84
# ...

# %%
df.head()
# Out:
#    Subject 1  Subject 2  Subject 3  Subject 4  Subject 5  Subject 6  \
# 0         94         34         40         82         66         68
# 1         63         96         32         49         68         87
# 2         89         97         77         95         43         32
# 3         34         86         46         49         84         94
# 4         99         45         63         71         46         58
#
#    Gain Marks
# 0         384
# 1         395
# 2         433
# 3         393
# 4         382

# %%
df['Percentage'] = df['Gain Marks'] / 600 * 100
df
# Out:
#     Subject 1  Subject 2  Subject 3  Subject 4  Subject 5  Subject 6  \
# 0          94         34         40         82         66         68
# 1          63         96         32         49         68         87
# 2          89         97         77         95         43         32
# 3          34         86         46         49         84         94
# 4          99         45         63         71         46         58
# 5          45         52         53         64         61         94
# 6          44         95         82         68         88         70
# 7          80         33         69         35         53         89
# 8          79         99         68         62         74         44
# 9          99         32         66         57         45         98
# 10         50         60         48         82         92         71
# 11         36         44         66         45         67         62
# 12         98         72         51         53         34         84
# ...
