# %%
#pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
result = model('image.jpg')
result[0].show()
# Out:
# image 1/1 C:\Users\User\Desktop\Poonam FBS\Data Science\YOLO\image.jpg: 448x640 1 person, 1 chair, 2 potted plants, 3 laptops, 155.4ms
# Speed: 10.3ms preprocess, 155.4ms inference, 16.7ms postprocess per image at shape (1, 3, 448, 640)

# %%
result
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
result1 = model('sandwitch.jpg')
result1[0].show()
# Out:
# image 1/1 C:\Users\User\Desktop\Poonam FBS\Data Science\YOLO\sandwitch.jpg: 384x640 2 sandwichs, 140.8ms
# Speed: 6.3ms preprocess, 140.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
