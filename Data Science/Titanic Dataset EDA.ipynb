# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Datasets/titanic_train.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.shape
# Out:
# (891, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Finding Null values are present or not and handle it

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Cabin'].shape
# Out:
# (891,)

# %%
data['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
mode = data['Cabin'].mode()
mode
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# Name: Cabin, dtype: object

# %%
median = data['Age'].median()
median
# Out:
# np.float64(28.0)

# %%
mean = data['Age'].mean()
mean
# Out:
# np.float64(29.69911764705882)

# %%
data['Age'] = data['Age'].fillna(median)

# %%
data['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
mode = data['Embarked'].mode()[0]
mode
# Out:
# 'S'

# %%
data['Embarked'] = data['Embarked'].fillna(mode)

# %%
data['Embarked'].isnull().sum()
# Out:
# np.int64(0)

# %%
data.drop('Cabin',axis = 1, inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %% [markdown]
# ### Finding outliers and handle outliers

# %%
def findOutliers(data, col):
    plt.figure(figsize = (10,5))
    plt.subplot(1, 2, 1)
    plt.boxplot(data[col])
    mean = data[col].mean()
    std = data[col].std()
    plt.subplot(1, 2, 2)
    sns.histplot(data, x = col, kde = True)
    plt.axvline(mean + 3 * std)
    plt.axvline(mean - 3 * std)

# %%
findOutliers(data, 'Survived')

# %%
findOutliers(data, 'Pclass')

# %%
findOutliers(data, 'Age')

# %%
findOutliers(data, 'SibSp')

# %%
findOutliers(data, 'Parch')

# %%
findOutliers(data, 'Fare')

# %%
# function for show outliers
def showOutliers(data, col):
    q1 = data[col].quantile(0.25)
    q3 = data[col].quantile(0.75)
    iqr = q3 - q1
    upper = q3 + (1.5 * iqr)
    lower = q1 - (1.5 * iqr)
    # print("Upper : " ,upper)
    # print("Lower : ", lower)
    return data[(data[col] < lower) | (data[col] > upper)]

# %%
showOutliers(data, 'Survived')
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
showOutliers(data, 'Pclass')
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
showOutliers(data, 'Age')
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 11            12         1       1
# 15            16         1       2
# 16            17         0       3
# 33            34         0       2
# ..           ...       ...     ...
# 827          828         1       2
# 829          830         1       1
# 831          832         1       2
# 851          852         0       3
# 879          880         1       1
#
#                                               Name     Sex    Age  SibSp  \
# 7                   Palsson, Master. Gosta Leonard    male   2.00      3
# 11                        Bonnell, Miss. Elizabeth  female  58.00      0
# 15                Hewlett, Mrs. (Mary D Kingcome)   female  55.00      0
# 16                            Rice, Master. Eugene    male   2.00      4
# 33                           Wheadon, Mr. Edward H    male  66.00      0
# ..                                             ...     ...    ...    ...
# ...

# %%
showOutliers(data, 'SibSp')
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 16            17         0       3
# 24            25         0       3
# 27            28         0       1
# 50            51         0       3
# 59            60         0       3
# 63            64         0       3
# 68            69         1       3
# 71            72         0       3
# 85            86         1       3
# 88            89         1       1
# 119          120         0       3
# 159          160         0       3
# 164          165         0       3
# 171          172         0       3
# 176          177         0       3
# 180          181         0       3
# 182          183         0       3
# 201          202         0       3
# 229          230         0       3
# 233          234         1       3
# 261          262         1       3
# 266          267         0       3
# 278          279         0       3
# 324          325         0       3
# ...

# %%
showOutliers(data, 'Parch')
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# ..           ...       ...     ...
# 871          872         1       1
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 16                                Rice, Master. Eugene    male   2.0      4
# ..                                                 ...     ...   ...    ...
# ...

# %%
showOutliers(data, 'Fare')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 52            53         1       1
# ..           ...       ...     ...
# 846          847         0       3
# 849          850         1       1
# 856          857         1       1
# 863          864         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  28.0      1
# 34                             Meyer, Mr. Edgar Joseph    male  28.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# function to handle outliers
def handleOutliers(data, col):
    q1 = data[col].quantile(0.25)
    q3 = data[col].quantile(0.75)
    iqr = q3 - q1
    upper = q3 + (1.5 * iqr)
    lower = q1 - (1.5 * iqr)
    data.loc[data[col] > upper , col] = upper 
    data.loc[data[col] < lower, col] = lower

# %%
handleOutliers(data, 'Age')

# %%
showOutliers(data, 'Age')
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
handleOutliers(data, 'SibSp')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_32176\1987439996.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[data[col] > upper , col] = upper

# %%
showOutliers(data, 'SibSp')
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
handleOutliers(data, 'Parch')

# %%
showOutliers(data, 'Parch')
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
handleOutliers(data, 'Fare')

# %%
showOutliers(data, 'Fare')
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %% [markdown]
# ### Finding Data is Imbalance or not and handle it

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['Sex'] = data['Sex'].replace({'male':0, 'female':1})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_32176\2717460279.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Sex'] = data['Sex'].replace({'male':0, 'female':1})

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
data['Embarked'] = data['Embarked'].replace({'S' : 0, 'C' : 1, 'Q' : 2})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_32176\2204192743.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Embarked'] = data['Embarked'].replace({'S' : 0, 'C' : 1, 'Q' : 2})

# %%
X = data.drop(['PassengerId','Survived','Name','Ticket'], axis = 1)
y = data['Survived']

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
X_sm, y_sm = sm.fit_resample(X, y)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.352413   29.039282
# std     257.353842    0.486592    0.836071    0.477990   12.072074
# min       1.000000    0.000000    1.000000    0.000000    2.500000
# 25%     223.500000    0.000000    2.000000    0.000000   22.000000
# 50%     446.000000    0.000000    3.000000    0.000000   28.000000
# 75%     668.500000    1.000000    3.000000    1.000000   35.000000
# max     891.000000    1.000000    3.000000    1.000000   54.500000
#
#             SibSp  Parch        Fare    Embarked
# count  891.000000  891.0  891.000000  891.000000
# mean     0.426487    0.0   24.046813    0.361392
# std      0.708246    0.0   20.481625    0.635673
# min      0.000000    0.0    0.000000    0.000000
# 25%      0.000000    0.0    7.910400    0.000000
# 50%      0.000000    0.0   14.454200    0.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_ss = ss.fit_transform(X_sm)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_ss, y_sm, test_size=0.2, random_state=42)
