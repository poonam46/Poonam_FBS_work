# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
#sample data
data = np.array([[10],[20],[30],[40]])
data.shape
# Out:
# (4, 1)

# %%
#Normalization
min_max = MinMaxScaler()
normalized = min_max.fit_transform(data)
normalized
# Out:
# array([[0.        ],
#        [0.33333333],
#        [0.66666667],
#        [1.        ]])

# %%
#Standardization
standard = StandardScaler()
standarized = standard.fit_transform(data)
standarized
# Out:
# array([[-1.34164079],
#        [-0.4472136 ],
#        [ 0.4472136 ],
#        [ 1.34164079]])
